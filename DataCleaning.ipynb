# %% [markdown]
# <a href="https://colab.research.google.com/github/Sid47wit/Ecommerce-Sales-Analysis/blob/main/DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('EcommerceSales.csv')

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03   1/7/2023  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04   1/8/2023  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-01-04   1/8/2023  Standard Class    PO-19195
# 3       4  US-2023-112326 2023-01-04   1/8/2023  Standard Class    PO-19195
# 4       5  US-2023-141817 2023-01-05  1/12/2023  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ...   Region  \
# 0  Darren Powers     Consumer  United States       Houston  ...  Central
# 1  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 2  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 3  Phillina Ober  Home Office  United States    Naperville  ...  Central
# 4     Mick Brown     Consumer  United States  Philadelphia  ...     East
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (10194, 22)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Month'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Month             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#              Row ID                     Order Date         Sales  \
# count  10194.000000                          10194  10194.000000
# mean    5097.500000  2025-04-29 11:48:25.002942720    228.225854
# min        1.000000            2023-01-03 00:00:00      0.444000
# 25%     2549.250000            2024-05-14 00:00:00     17.220000
# 50%     5097.500000            2025-06-25 00:00:00     53.910000
# 75%     7645.750000            2026-05-14 00:00:00    209.500000
# max    10194.000000            2026-12-30 00:00:00  22638.480000
# std     2942.898656                            NaN    619.906839
#
#            Quantity      Discount        Profit         Month
# count  10194.000000  10194.000000  10194.000000  10194.000000
# mean       3.791838      0.155385     28.673417      7.811850
# min        1.000000      0.000000  -6599.978000      1.000000
# 25%        2.000000      0.000000      1.760800      5.000000
# 50%        3.000000      0.200000      8.690000      9.000000
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Month_Name'] = df['Order Date'].dt.month_name()

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03   1/7/2023  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04   1/8/2023  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-01-04   1/8/2023  Standard Class    PO-19195
# 3       4  US-2023-112326 2023-01-04   1/8/2023  Standard Class    PO-19195
# 4       5  US-2023-141817 2023-01-05  1/12/2023  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ...  \
# 0  Darren Powers     Consumer  United States       Houston  ...
# 1  Phillina Ober  Home Office  United States    Naperville  ...
# 2  Phillina Ober  Home Office  United States    Naperville  ...
# 3  Phillina Ober  Home Office  United States    Naperville  ...
# 4     Mick Brown     Consumer  United States  Philadelphia  ...
#
#           Category Sub-Category  \
# 0  Office Supplies        Paper
# 1  Office Supplies      Binders
# ...

# %%
df['Profit_Margin'] = (df['Profit'] / df['Sales']) * 100

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03   1/7/2023  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04   1/8/2023  Standard Class    PO-19195
# 2       3  US-2023-112326 2023-01-04   1/8/2023  Standard Class    PO-19195
# 3       4  US-2023-112326 2023-01-04   1/8/2023  Standard Class    PO-19195
# 4       5  US-2023-141817 2023-01-05  1/12/2023  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Sub-Category  \
# 0  Darren Powers     Consumer  United States       Houston  ...        Paper
# 1  Phillina Ober  Home Office  United States    Naperville  ...      Binders
# 2  Phillina Ober  Home Office  United States    Naperville  ...       Labels
# 3  Phillina Ober  Home Office  United States    Naperville  ...      Storage
# 4     Mick Brown     Consumer  United States  Philadelphia  ...          Art
#
# ...

# %%
sales_region = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)

sales_region
# Out:
# Region
# West       739813.6085
# East       691828.1680
# Central    503170.6728
# South      391721.9050
# Name: Sales, dtype: float64

# %%
sales_region.plot(kind='bar')

plt.title("Total Sales by Region")
plt.ylabel("Sales")
plt.xlabel("Region")

plt.show()

# %%
sales_category = df.groupby('Category')['Sales'].sum()

sales_category
# Out:
# Category
# Furniture          754747.7613
# Office Supplies    731893.3140
# Technology         839893.2790
# Name: Sales, dtype: float64

# %%
sales_category.plot(kind='bar')

plt.title("Sales by Category")
plt.ylabel("Sales")

plt.show()

# %%
monthly_sales = df.groupby('Month_Name')['Sales'].sum()

monthly_sales
# Out:
# Month_Name
# April        138098.7486
# August       161821.9150
# December     330218.1755
# February      59751.2514
# January       96069.5156
# July         149001.7130
# June         153459.9973
# March        210672.0868
# May          158765.0337
# November     352665.9910
# October      207126.2567
# September    308883.6697
# Name: Sales, dtype: float64

# %%
monthly_sales.plot(kind='line', marker='o')

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

top_products
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
top_products.plot(kind='bar')

plt.title("Top 10 Products by Sales")
plt.ylabel("Sales")

plt.show()

# %%
profit_category = df.groupby('Category')['Profit'].sum()

profit_category
# Out:
# Category
# Furniture           19729.9956
# Office Supplies    126023.4434
# Technology         146543.3756
# Name: Profit, dtype: float64

# %%
profit_category.plot(kind='bar')

plt.title("Profit by Category")

plt.show()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Month', 'Year', 'Month_Name', 'Profit_Margin'],
#       dtype='object')

# %%
corr = df[['Sales','Profit','Discount','Quantity']].corr()

sns.heatmap(corr, annot=True)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# #Insight 1
# West region contributes the highest revenue.
# #Insight 2
# Electronics category generates the highest sales.
# #Insight 3
# High discounts negatively impact profit margins.
# #Insight 4
# Few products contribute to the majority of revenue.

# %%
df.to_csv("cleaned_ecommerce_data.csv", index=False)
